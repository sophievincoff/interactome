# %% [markdown]
# This .ipynb file will be used to compile SNOOPPI-XL, which includes the gold-standard IntAct data, as well as:
#     * Protein-protein and protein-peptide pairs from PPIRef
#     * Peptide-peptide pairs from PepMLM's training data
#     * Protein-peptide pairs from BioLiP2
#     * The negative manual-stringent database from Negatome2.0

# %%
import pandas as pd

# %% [markdown]
# # Define filepaths

# %%
# PepMLM processed positive interactions
pepmlm_pos = pd.read_csv("/scratch/pranamlab/sophie/interactome/interactome/data_files/processed/pepmlm/full_seq_pairs.csv")

# PPIRef processed positive interactions
ppiref_pos = None


negatome_neg = None



intact_savedir = "/scratch/pranamlab/sophie/interactome/interactome/data_files/processed/intact/clean"
intact_pos = pd.read_csv(f"{intact_savedir}/mi0407_ptm_and_mut_and_bindsite.csv")
intact_unknown = pd.read_csv(f"{intact_savedir}/mi0407_unknown_ptm_and_mut_and_bindsite.csv")
intact_neg = pd.read_csv(f"{intact_savedir}/mi0407_neg_ptm_and_mut_and_bindsite.csv")
